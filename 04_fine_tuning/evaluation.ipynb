# %% [markdown]
# # Model Evaluation
#
# Comparing **base models** against **fine-tuned checkpoints** to measure improvement.
#
# ## Topics
# - Evaluation metrics: perplexity, BLEU, ROUGE, BERTScore
# - Side-by-side qualitative comparison
# - Using HuggingFace `evaluate` library
# - LLM-as-judge evaluation patterns
# - Tracking experiments with logging

# %%
# Your code here
