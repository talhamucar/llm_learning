# %% [markdown]
# # Dataset Preparation
#
# Curating, cleaning, and formatting **JSONL** data for fine-tuning.
#
# ## Topics
# - What makes a good fine-tuning dataset?
# - JSONL format: instruction/input/output and chat formats
# - Data cleaning: deduplication, length filtering, quality checks
# - Using HuggingFace `datasets` library
# - Train/validation splits

# %%
# Your code here
