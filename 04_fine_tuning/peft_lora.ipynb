# %% [markdown]
# # PEFT & LoRA Fine-Tuning
#
# Using **Parameter-Efficient Fine-Tuning** to train models without massive compute.
#
# ## Topics
# - Why PEFT? Full fine-tuning vs adapter methods
# - LoRA (Low-Rank Adaptation) explained
# - QLoRA: quantized LoRA for consumer GPUs
# - Setting up training with HuggingFace `peft` + `trl`
# - Saving and merging LoRA adapters

# %%
# Your code here
