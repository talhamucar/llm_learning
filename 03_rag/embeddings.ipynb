# %% [markdown]
# # Embeddings
#
# Comparing different embedding models: **OpenAI** vs **HuggingFace**.
#
# ## Topics
# - What are embeddings and how are they generated?
# - OpenAI `text-embedding-3-small` / `text-embedding-3-large`
# - HuggingFace `sentence-transformers` models
# - Cosine similarity and distance metrics
# - Benchmarking embedding quality

# %%
# Your code here
