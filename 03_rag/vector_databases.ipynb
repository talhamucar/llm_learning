# %% [markdown]
# # Vector Databases
#
# Indexing and searching data with **ChromaDB**, **Pinecone**, and **FAISS**.
#
# ## Topics
# - What is a vector database and why it matters for RAG
# - ChromaDB: local and persistent collections
# - FAISS: high-performance similarity search
# - Pinecone: managed cloud vector store
# - CRUD operations on vector stores

# %%
# Your code here
