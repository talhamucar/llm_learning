# %% [markdown]
# # Knowledge Retrieval
#
# Implementing **semantic search**, **re-ranking**, and **context window management**.
#
# ## Topics
# - Full RAG pipeline: ingest → embed → retrieve → generate
# - Semantic search with top-k retrieval
# - Re-ranking retrieved chunks for relevance
# - Managing context window limits
# - Chunking strategies: fixed-size, sentence, recursive

# %%
# Your code here
