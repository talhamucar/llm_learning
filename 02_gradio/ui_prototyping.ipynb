# %% [markdown]
# # UI Prototyping with Gradio
#
# Building web interfaces for LLMs in minutes using **Gradio**.
#
# ## Topics
# - Gradio basics: `gr.Interface` and `gr.Blocks`
# - Connecting a Gradio UI to an LLM API
# - Input/output components: text, dropdowns, sliders
# - Launching and sharing demos

# %%
# Your code here
