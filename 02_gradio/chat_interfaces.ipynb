# %% [markdown]
# # Chat Interfaces with Gradio
#
# Creating persistent chat histories and real-time **streaming** responses.
#
# ## Topics
# - `gr.ChatInterface` for multi-turn conversations
# - Maintaining chat history across turns
# - Streaming tokens in real-time with `yield`
# - System prompts and conversation state

# %%
# Your code here
