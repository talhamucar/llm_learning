# %% [markdown]
# # Tokenization
#
# Deep dive into how LLMs break text into tokens using **BPE** and **SentencePiece**.
#
# ## Topics
# - What is a token? Byte-Pair Encoding (BPE) explained
# - Using `tiktoken` (OpenAI tokenizer)
# - Using `sentencepiece` (Google/Meta tokenizer)
# - How token limits affect cost and context windows
# - Comparing tokenization across different models

# %%
# Your code here
