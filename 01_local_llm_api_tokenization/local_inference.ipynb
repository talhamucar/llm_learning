# %% [markdown]
# # Local Inference
#
# Running LLMs on your own hardware using **Ollama** and **LM Studio**.
#
# ## Topics
# - Installing and running Ollama
# - Pulling and querying models locally
# - Using LM Studio as a local OpenAI-compatible server
# - Comparing local vs cloud latency and cost

# %%
# Your code here
