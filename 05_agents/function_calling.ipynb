# %% [markdown]
# # Function Calling
#
# Teaching LLMs to use **external tools**, calculators, and APIs.
#
# ## Topics
# - OpenAI function calling / tool use
# - Defining tool schemas in JSON
# - Parsing and executing tool calls from model output
# - Returning tool results back to the model
# - Building a calculator and web search tool

# %%
# Your code here
