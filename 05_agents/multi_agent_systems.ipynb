# %% [markdown]
# # Multi-Agent Systems
#
# Coordinating **specialized agents** to solve complex, multi-step tasks.
#
# ## Topics
# - Why multi-agent? Specialization and parallelism
# - Orchestrator + worker agent pattern
# - Agent communication and shared memory
# - Building a research + writer agent pipeline
# - Evaluation and monitoring of multi-agent systems

# %%
# Your code here
