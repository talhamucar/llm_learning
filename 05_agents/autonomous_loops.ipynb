# %% [markdown]
# # Autonomous Loops (ReAct Agents)
#
# Building **ReAct** agents that can "think" and "act" sequentially.
#
# ## Topics
# - The ReAct pattern: Reasoning + Acting
# - Thought → Action → Observation loop
# - Building a ReAct agent from scratch
# - Stopping conditions and safety guardrails
# - Debugging agent trajectories

# %%
# Your code here
